# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from agent_system.environments.env_package.habitat_sim.utils.habitat_utils import get_dataset_subfolder

# %%
scene_subfolder = get_dataset_subfolder("ReplicaCAD")
print(scene_subfolder)
print(len(scene_subfolder))
# Out:
# ['v3_sc3_staging_18.scene_instance.json', 'v3_sc0_staging_13.scene_instance.json', 'v3_sc1_staging_00.scene_instance.json', 'v3_sc0_staging_18.scene_instance.json', 'v3_sc3_staging_10.scene_instance.json', 'v3_sc1_staging_16.scene_instance.json', 'v3_sc1_staging_04.scene_instance.json', 'v3_sc3_staging_20.scene_instance.json', 'v3_sc0_staging_09.scene_instance.json', 'v3_sc2_staging_09.scene_instance.json', 'v3_sc1_staging_12.scene_instance.json', 'v3_sc2_staging_13.scene_instance.json', 'v3_sc1_staging_18.scene_instance.json', 'v3_sc1_staging_19.scene_instance.json', 'v3_sc2_staging_08.scene_instance.json', 'v3_sc1_staging_20.scene_instance.json', 'v3_sc2_staging_03.scene_instance.json', 'v3_sc1_staging_02.scene_instance.json', 'v3_sc3_staging_09.scene_instance.json', 'v3_sc3_staging_11.scene_instance.json', 'v3_sc0_staging_08.scene_instance.json', 'v3_sc2_staging_19.scene_instance.json', 'v3_sc2_staging_11.scene_instance.json', 'v3_sc0_staging_19.scene_instance.json', 'v3_sc2_stagi
# ...

# %%
print(scene_subfolder[:10])
print(scene_subfolder[10:20])
# Out:
# ['v3_sc3_staging_18.scene_instance.json', 'v3_sc0_staging_13.scene_instance.json', 'v3_sc1_staging_00.scene_instance.json', 'v3_sc0_staging_18.scene_instance.json', 'v3_sc3_staging_10.scene_instance.json', 'v3_sc1_staging_16.scene_instance.json', 'v3_sc1_staging_04.scene_instance.json', 'v3_sc3_staging_20.scene_instance.json', 'v3_sc0_staging_09.scene_instance.json', 'v3_sc2_staging_09.scene_instance.json']
# ['v3_sc1_staging_12.scene_instance.json', 'v3_sc2_staging_13.scene_instance.json', 'v3_sc1_staging_18.scene_instance.json', 'v3_sc1_staging_19.scene_instance.json', 'v3_sc2_staging_08.scene_instance.json', 'v3_sc1_staging_20.scene_instance.json', 'v3_sc2_staging_03.scene_instance.json', 'v3_sc1_staging_02.scene_instance.json', 'v3_sc3_staging_09.scene_instance.json', 'v3_sc3_staging_11.scene_instance.json']
